# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('UberDataset.csv')

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
df.drop(1155,axis=0,inplace=True)

# %%
df['START_DATE']=pd.to_datetime(df['START_DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 63.3+ KB

# %%
df.dropna(subset=['END_DATE'], inplace=True)

# %%
df['END_DATE']=pd.to_datetime(df['END_DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

df['date']=pd.DatetimeIndex(df['START_DATE']).date

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01
# 1      Fort Pierce    5.0              NaN  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06

# %%
df['time']=pd.DatetimeIndex(df['START_DATE']).hour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
#  7   date        1155 non-null   object
#  8   time        1155 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(5)
# memory usage: 81.3+ KB

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21
# 1      Fort Pierce    5.0              NaN  2016-01-02     1
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14

# %%
df['day-night'] = pd.cut(x=df['time'],
                              bins = [0,10,15,19,24],
                              labels = ['Morning','Afternoon','Evening','Night'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
#  7   date        1155 non-null   object
#  8   time        1155 non-null   int64
#  9   day-night   1136 non-null   category
# dtypes: category(1), datetime64[ns](2), float64(1), int64(1), object(5)
# memory usage: 82.7+ KB

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon

# %%
# creating a new label called Duration of the journey

df['starting_hour']=pd.DatetimeIndex(df['START_DATE']).hour
df['starting_min']=pd.DatetimeIndex(df['START_DATE']).minute

df['ending_hour']=pd.DatetimeIndex(df['END_DATE']).hour
df['ending_min']=pd.DatetimeIndex(df['END_DATE']).minute

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    starting_hour  starting_min  ending_hour  ending_min
# 0             21            11           21          17
# ...

# %%
df['duration_hr']=df['ending_hour']-df['starting_hour']

# %%
df['duration_min']=df['ending_min']-df['starting_min']

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    starting_hour  starting_min  ending_hour  ending_min  duration_hr  \
# ...

# %%
df['Journey_duration']=df['duration_hr']*60+df['duration_min']

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    starting_hour  starting_min  ending_hour  ending_min  duration_hr  \
# ...

# %%
df.drop(columns=['starting_hour','starting_min','ending_hour','ending_min'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    duration_hr  duration_min  Journey_duration
# 0            0             6                 6
# ...

# %%
df.drop(columns=['duration_hr','duration_min'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    Journey_duration
# 0                 6
# 1                12
# 2                13
# 3                14
# 4                67

# %%
df['CATEGORY'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['PURPOSE'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE, dtype: int64

# %%
df['PURPOSE'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Meeting have the majority number of ride in the company

# %%
df['day-night'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# In the afternoon the numnber of rides are greater than other time

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df,x='PURPOSE',hue='CATEGORY')
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# INSIGHT OF THE VISULIZATION
#
# 1.Most of the rides are booked for Bussiness purpose
# 2.Most of the people book cab for Meeting and Meal/Entertain purpose
# 3.Most of the cabs are booked in the 10am - 5pm (Afternoon)

# %%
df['month']=pd.DatetimeIndex(df['START_DATE']).month

# %%
month_label={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

df['month']=df.month.map(month_label)

# %%
df.tail()
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES         PURPOSE        date  time  day-night  \
# 1150           Kar?chi    0.7         Meeting  2016-12-31     1    Morning
# 1151  Unknown Location    3.9  Temporary Site  2016-12-31    13  Afternoon
# 1152  Unknown Location   16.2         Meeting  2016-12-31    15  Afternoon
# 1153           Gampaha    6.4  Temporary Site  2016-12-31    21      Night
# 1154         Ilukwatta   48.2  Temporary Site  2016-12-31    22      Night
#
#       Journey_duration month
# 1150                 7   Dec
# ...

# %%
mon=df.month.value_counts(sort=False)

# %%
mon
# Out:
# Jan     61
# Feb    115
# Mar    113
# Apr     54
# May     49
# Jun    108
# Jul    112
# Aug    133
# Sep     36
# Oct    106
# Nov    122
# Dec    146
# Name: month, dtype: int64

# %%
dataset = pd.DataFrame({"MONTHS": mon.values,
                   "VALUE COUNT": df.groupby('month',
                                                  sort=False)['MILES'].max()})

# %%
dataset
# Out:
#        MONTHS  VALUE COUNT
# month
# Jan        61         63.7
# Feb       115         43.7
# Mar       113        310.3
# Apr        54        174.2
# May        49         25.6
# Jun       108         46.9
# Jul       112        195.3
# Aug       133        156.9
# Sep        36        195.6
# Oct       106        195.9
# Nov       122         45.9
# Dec       146        103.0

# %%
p=sns.lineplot(data=dataset)
p.set(xlabel='MONTHS',ylabel='VALUE COUNT')
# Out:
# [Text(0.5, 0, 'MONTHS'), Text(0, 0.5, 'VALUE COUNT')]

# %%
plt.figure(figsize=(10,5))
df['month'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# INSIGHT OF THE VISULIZATION
#
# 1. IN THE MONTH OF FEB,MAR,JUN,JULY,OCT,NOV AND DEC HAVE THE MOST NUMBER OF RIDES
# 2. IN THE MONTH OF JAN,APR,MAY AND SEP HAVE THE LEAST NUMBER OF CAB RIDES

# %%
df['day']=pd.DatetimeIndex(df['START_DATE']).weekday

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    Journey_duration month  day
# 0                 6   Jan    4
# 1                12   Jan    5
# 2                13   Jan    5
# ...

# %%
df['day'].value_counts()
# Out:
# 4    206
# 1    176
# 0    174
# 3    154
# 5    150
# 6    148
# 2    147
# Name: day, dtype: int64

# %%
day_label={0:'Sun',1:'Mon',2:'Tus',3:'Wed',4:'Thus',5:'Fri',6:'Sat'}

df['day']=df['day'].map(day_label)

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1      Fort Pierce    5.0              NaN  2016-01-02     1    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
#
#    Journey_duration month   day
# 0                 6   Jan  Thus
# 1                12   Jan   Fri
# 2                13   Jan   Fri
# ...

# %%
day_label=df.day.value_counts()

sns.barplot(x=day_label.index,y=day_label)
plt.xlabel('DAY')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
sns.displot(df[df['MILES']>50]['MILES'])

# %%
sns.distplot(df[df['MILES']<50]['MILES'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_20692\2793782046.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['MILES']<50]['MILES'])
# <Axes: xlabel='MILES', ylabel='Density'>

# %% [raw]
# INSIGHT OF THE VISULIZATION
# 1. MOST OF THE CABS BOOKED FOR THE 4-5 MILES
# 2. MOJORITY OF PEOPLE CHOOSES CABS FOR THE LESS THAN 20 MILES
# 3. GREATER THAN 20 MILES DISTANCES ARE NEGLIGIBLE

# %%
df.groupby('START').size()
# Out:
# START
# Agnew               4
# Almond              1
# Apex               17
# Arabi               1
# Arlington           1
#                    ..
# West University     2
# Weston              2
# Westpark Place     17
# Whitebridge        68
# Winston Salem       1
# Length: 177, dtype: int64

# %%
temp=pd.DataFrame(df.groupby('START').size()).nlargest(10,columns=0).reset_index(drop=False)
plt.figure(figsize=(10,6))
plt.title('TOP 10 STARTING LOCATION')
sns.barplot(data=temp,x='START',y=0)
plt.xticks(rotation=90)
plt.show()

# %%
temp=pd.DataFrame(df.groupby('STOP').size()).nlargest(10,columns=0).reset_index(drop=False)
plt.figure(figsize=(10,6))
plt.title('TOP 10 ENDING LOCATION')
sns.barplot(data=temp,x='STOP',y=0)
plt.xticks(rotation=90)
plt.show()

# %%
temp
# Out:
#                STOP    0
# 0              Cary  203
# 1  Unknown Location  149
# 2       Morrisville   84
# 3       Whitebridge   65
# 4         Islamabad   58
# 5            Durham   36
# 6            Lahore   36
# 7           Raleigh   29
# 8           Kar?chi   26
# 9              Apex   17

# %%
df['STOP'].value_counts()
# Out:
# Cary                 203
# Unknown Location     149
# Morrisville           84
# Whitebridge           65
# Islamabad             58
#                     ...
# Daytona Beach          1
# Sand Lake Commons      1
# Sky Lake               1
# Vista East             1
# Ilukwatta              1
# Name: STOP, Length: 188, dtype: int64
